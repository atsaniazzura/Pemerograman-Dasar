# %% [markdown]
# <a href="https://colab.research.google.com/github/atsaniazzura/Pemerograman-Dasar/blob/main/pertemuan_2_Pemerograman_dasar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("halo, Phyton! -Praktikum TRPE")
# Out:
# halo, Phyton! -Praktikum TRPE

# %%
#l1
tegangan_panel = 18
arus_panel = 6
jenis_sel = 'monocrystalline'

print (tegangan_panel)
print (arus_panel)
print (jenis_sel)
# Out:
# 18
# 6
# monocrystalline

# %%
#L2
"motor"
tegangan_motor = 220
arus_motor = 15.5
status_motor = "mati"
berfungsi = True

print (type (tegangan_motor))
print (type (arus_motor))
print (type (status_motor))
print (type (berfungsi))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#L3
Nama_unit = "PLTS Nunukan"
jumlah_panel = 240
Tegangan_keluaran = 48.5
Sedang_beroperasi = True

print (type (Nama_unit))
print (type (jumlah_panel))
print (type (Tegangan_keluaran))
print (type (Sedang_beroperasi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#L4
Tegangan_harian = {217.5, 219.0, 220.3, 218.7, 221.1, 216.9}
tegangan_tambahan = (222.0)
jumlah_total = (222.0)
print (Tegangan_harian)
print (tegangan_tambahan)
print (jumlah_total)
# Out:
# {216.9, 217.5, 218.7, 219.0, 220.3, 221.1}
# 222.0
# 222.0

# %%
#L5
motor_listrik = {'nama': "hitachi", 'daya_kw': 64.5, 'tegangan_V': 220, 'rpm': 2500 }
print (motor_listrik['nama'])
motor_listrik ['rpm'] = 3000
print (motor_listrik)
# Out:
# hitachi
# {'nama': 'hitachi', 'daya_kw': 64.5, 'tegangan_V': 220, 'rpm': 3000}

# %%
#L6
# Jawaban Latihan 6
pembangkit =[
{"PLTU": 'unit-1', 'Kapasitas_MW': 100, 'status': 'operasi'},
{"PLTA": 'unit-2', 'Kapasitas_MW': 150, 'status': 'operasi'},
{"PLTS": 'unit-3', 'Kapasitas_MW': 80, 'status': 'pemeliharaan'},
]

print  (pembangkit [1]["PLTA"])
pembangkit [2]["status"] = "operasi"
pembangkit.append({"PLTA": "unit-2", "Kapasitas_MW": 100, "status": "pemeliharaan"})
print ("\n2.Seluruh data pembangkit setelah diperbarui:")
for unit in pembangkit:
  print (unit)
# Out:
# unit-2
#
# 2.Seluruh data pembangkit setelah diperbarui:
# {'PLTU': 'unit-1', 'Kapasitas_MW': 100, 'status': 'operasi'}
# {'PLTA': 'unit-2', 'Kapasitas_MW': 150, 'status': 'operasi'}
# {'PLTS': 'unit-3', 'Kapasitas_MW': 80, 'status': 'operasi'}
# {'PLTA': 'unit-2', 'Kapasitas_MW': 100, 'status': 'pemeliharaan'}
