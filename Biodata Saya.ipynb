# %% [markdown]
# <a href="https://colab.research.google.com/github/atsaniazzura/Pemerograman-Dasar/blob/main/Biodata%20Saya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata Saya

nama = "Zura"
nim = "4232501011"
kewarganegaraan = "indonesia"
umur = 20
jeniskelamin = "lakilaki"
asalsekolah = "smkn 1 Bukittinggi"
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
gmail = "atsaniazzura0@gmail.com"
status_lulus = False


print (nama)
print (nim)
print (kewarganegaraan)
print (umur)
print (jeniskelamin)
print (asalsekolah)
print (jurusan)
print (semester)
print (matakuliah)
print (gmail)
print (status_lulus)
# Out:
# Zura
# 4232501011
# indonesia
# 20
# lakilaki
# smkn 1 Bukittinggi
# RPE
# 3
# Pemerograman Dasar
# atsaniazzura0@gmail.com
# False
